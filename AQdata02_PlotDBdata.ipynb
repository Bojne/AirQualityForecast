# %% [markdown]
# # Air Quality Dataset

# %%
import pandas as pd
# %matplotlib inline
# %pylab inline
import pprint

# To plot pretty figures
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.style.use('ggplot')
pylab.rcParams['figure.figsize'] = (20, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('./AQdata_clean.csv')

# %%
df.columns
# Out:
# Index(['DateTime', 'idx', 'Date', 'Day', 'Hour', 'Weekday', 'Week', 'Month',
#        'PT08.S1(CO)', 'PT08.S2(NMHC)', 'PT08.S3(NOx)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'CO(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)', 'T', 'RH',
#        'AH', 'ewma'],
#       dtype='object')

# %%
dailyMax = df.groupby('Date').max()
dailyMean = df.groupby('Date').mean()
dailyMean365 = dailyMean[:365]

# %%
dailyMean365.shape
# Out:
# (365, 19)

# %%
dailyMean['ewma'].plot()

# %%
dailyMax.to_csv('AQdata_dailyMax.csv')
dailyMean.to_csv('AQdata_dailyMean.csv')
dailyMean.to_csv("dailyMean365.csv")

# %% [markdown]
# ## Split into test and train set

# %%
df.set_index('DateTime')
# Out:
#                       idx        Date  Day  Hour  Weekday  Week  Month  \
# DateTime
# 2004-03-10 18:00:00     0  2004-03-10   10    18        2    11      3
# 2004-03-10 19:00:00     1  2004-03-10   10    19        2    11      3
# 2004-03-10 20:00:00     2  2004-03-10   10    20        2    11      3
# 2004-03-10 21:00:00     3  2004-03-10   10    21        2    11      3
# 2004-03-10 22:00:00     4  2004-03-10   10    22        2    11      3
# 2004-03-10 23:00:00     5  2004-03-10   10    23        2    11      3
# 2004-03-11 00:00:00     6  2004-03-11   11     0        3    11      3
# 2004-03-11 01:00:00     7  2004-03-11   11     1        3    11      3
# 2004-03-11 02:00:00     8  2004-03-11   11     2        3    11      3
# 2004-03-11 03:00:00     9  2004-03-11   11     3        3    11      3
# 2004-03-11 04:00:00    10  2004-03-11   11     4        3    11      3
# 2004-03-11 05:00:00    11  2004-03-11   11     5        3    11      3
# ...

# %%
24*340
# Out:
# 8160

# %%
# df_with_dummies = pd.get_dummies( df, columns = ['Weekday'])

# %%
year_data = df[:24*340]
test_data = df[24*340:]
train_data.to_csv('train8160.csv')
test_data.to_csv('test1197.csv')
